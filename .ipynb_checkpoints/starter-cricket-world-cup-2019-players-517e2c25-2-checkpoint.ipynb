# %% [markdown]
# ## Introduction
# The objective of this project was to perform an exploratory data analysis of the cricket world cup dataset. The dataset contains information on all matches played in the cricket world cup. The analysis was conducted using the Python programming language and the following libraries: pandas, matplotlib, numpy, sklearn.

# %% [markdown]
# ## Exploratory Analysis
# To begin this exploratory analysis, first import libraries and define functions for plotting the data using `matplotlib`. Depending on the data, not all plots will be made.

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# There are 6 csv files in the current version of the dataset:

# %%
print(os.listdir('../input'))
# Out:
# ['ODI_Match_Totals.csv', 'Batsman_Data.csv', 'Ground_Averages.csv', 'WC_players.csv', 'Bowler_data.csv', 'ODI_Match_Results.csv']

# %% [markdown]
# The next hidden code cells define functions for plotting data. Click on the "Code" button in the published kernel to reveal the hidden code.

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %% [markdown]
# Now you're ready to read in the data and use the plotting functions to visualize the data.

# %% [markdown]
# ### Let's check 1st file: ../input/Batsman_Data.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# Batsman_Data.csv has 11149 rows in reality, but we are only loading/previewing the first 1000 rows
df1 = pd.read_csv('../input/Batsman_Data.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'Batsman_Data.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 13 columns

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df1.head(5)
# Out:
#    Unnamed: 0 Bat1 Runs    ...       Match_ID        Batsman Player_ID
# 0           1  DNB    -    ...     ODI # 2933  Oshane Thomas     49619
# 1           2  DNB    -    ...     ODI # 2935  Oshane Thomas     49619
# 2           3  DNB    -    ...     ODI # 2936  Oshane Thomas     49619
# 3           4  DNB    -    ...     ODI # 2937  Oshane Thomas     49619
# 4           5  DNB    -    ...     ODI # 2938  Oshane Thomas     49619
#
# [5 rows x 13 columns]

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
plotPerColumnDistribution(df1, 10, 5)

# %% [markdown]
# Correlation matrix:

# %%
plotCorrelationMatrix(df1, 8)

# %% [markdown]
# ### Let's check 2nd file: ../input/Bowler_data.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# Bowler_data.csv has 11118 rows in reality, but we are only loading/previewing the first 1000 rows
df2 = pd.read_csv('../input/Bowler_data.csv', delimiter=',', nrows = nRowsRead)
df2.dataframeName = 'Bowler_data.csv'
nRow, nCol = df2.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 14 columns

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df2.head(5)
# Out:
#    Unnamed: 0 Overs Mdns    ...       Match_ID          Bowler Player_ID
# 0           1   8.0    0    ...     ODI # 2933  Suranga Lakmal     49619
# 1           2  10.0    0    ...     ODI # 2935  Suranga Lakmal     49619
# 2           3     -    -    ...     ODI # 2936  Suranga Lakmal     49619
# 3           4   9.0    1    ...     ODI # 2937  Suranga Lakmal     49619
# 4           5   8.0    1    ...     ODI # 2938  Suranga Lakmal     49619
#
# [5 rows x 14 columns]

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
plotPerColumnDistribution(df2, 10, 5)

# %% [markdown]
# Correlation matrix:

# %%
plotCorrelationMatrix(df2, 8)

# %% [markdown]
# ### Let's check 3rd file: ../input/Ground_Averages.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df3 = pd.read_csv('../input/Ground_Averages.csv', delimiter=',', nrows = nRowsRead)
df3.dataframeName = 'Ground_Averages.csv'
nRow, nCol = df3.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 106 rows and 11 columns

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df3.head(5)
# Out:
#                                               Ground  ...    RPO
# 0                      Eden Gardens, Kolkata - India  ...   5.64
# 1                    Feroz Shah Kotla, Delhi - India  ...   4.60
# 2               Melbourne Cricket Ground - Australia  ...   5.41
# 3  Saurashtra Cricket Association Stadium, Rajkot...  ...   5.81
# 4                          Adelaide Oval - Australia  ...   5.16
#
# [5 rows x 11 columns]

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
plotPerColumnDistribution(df3, 10, 5)

# %% [markdown]
# Correlation matrix:

# %%
plotCorrelationMatrix(df3, 8)

# %% [markdown]
# Scatter and density plots:

# %%
plotScatterMatrix(df3, 20, 10)

# %% [markdown]
# ## Conclusion
# The exploratory data analysis of the cricket world cup dataset has provided a number of insights into the history of the tournament. The analysis can be used to inform future strategic decisions by teams and cricket governing bodies. Additionally, the analysis can be used to generate new hypotheses that can be tested with further data analysis.
